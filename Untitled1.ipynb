# %%
import numpy as np
import tifffile as tiff

# load npy
metal_trace = np.load(r'D:\NMAR\Case_02_MFOV_Foot\cbrecon\2.16.840.114490.20251103153455_fdk_hu.npy')

# save as TIFF
tiff.imwrite(r"D:\NMAR\Case_02_MFOV_Foot\cbrecon\fdk_hu.npy.tiff", metal_trace)
